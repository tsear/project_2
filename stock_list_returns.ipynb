# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %% [markdown]
# multiple_df

# %%
tickers = ['AAPL', 'TSLA', 'JPM', 'ADBE', 'AMD', 'NVDA', 'AMZN',
           'FB', 'LRCX', 'MSFT', 'DPZ', 'MCD', 'CMG', 'LULU',
           'CRM', 'NOW', 'V', 'MA', 'AXP', 'GOOGL', 'NFLX', 'UNH',
           'ROG', 'HD', 'GD', 'FDX',  'COST', 'NKE']

# %%
multiple_df = yf.download(tickers, rounding=True)['Adj Close'][tickers].pct_change()
# Out:
# [*********************100%***********************]  28 of 28 completed

# %%
multiple_df.tail()
# Out:
#                 AAPL      TSLA       JPM      ADBE       AMD      NVDA  \
# Date
# 2022-06-17  0.011533  0.017175 -0.003526 -0.011751 -0.005850  0.017883
# 2022-06-21  0.032761  0.093544  0.024772  0.006098  0.027216  0.043199
# 2022-06-22 -0.003827 -0.004008 -0.005612  0.006446 -0.000477 -0.012435
# 2022-06-23  0.021574 -0.004306 -0.010939  0.030958 -0.015761 -0.008252
# 2022-06-24  0.024517  0.045249  0.029846  0.029418  0.056412  0.055532
#
#                 AMZN        FB      LRCX      MSFT  ...       AXP     GOOGL  \
# Date                                                ...
# 2022-06-17  0.024696  0.017840  0.002773  0.010940  ...  0.048582  0.010468
# 2022-06-21  0.023159 -0.040857  0.032375  0.024591  ...  0.004023  0.041071
# 2022-06-22  0.002484 -0.007641 -0.017112 -0.002404  ... -0.002556 -0.000507
# 2022-06-23  0.032033  0.018608 -0.003642  0.022637  ... -0.018976  0.006768
# 2022-06-24  0.035752  0.071874  0.061569  0.034150  ...  0.031768  0.051077
#
# ...

# %%
multiple_df = multiple_df.reset_index(drop=True)

# %%
multiple_df.tail()
# Out:
#            AAPL      TSLA       JPM      ADBE       AMD      NVDA      AMZN  \
# 15221  0.011533  0.017175 -0.003526 -0.011751 -0.005850  0.017883  0.024696
# 15222  0.032761  0.093544  0.024772  0.006098  0.027216  0.043199  0.023159
# 15223 -0.003827 -0.004008 -0.005612  0.006446 -0.000477 -0.012435  0.002484
# 15224  0.021574 -0.004306 -0.010939  0.030958 -0.015761 -0.008252  0.032033
# 15225  0.024517  0.045249  0.029846  0.029418  0.056412  0.055532  0.035752
#
#              FB      LRCX      MSFT  ...       AXP     GOOGL      NFLX  \
# 15221  0.017840  0.002773  0.010940  ...  0.048582  0.010468  0.012460
# 15222 -0.040857  0.032375  0.024591  ...  0.004023  0.041071 -0.026209
# 15223 -0.007641 -0.017112 -0.002404  ... -0.002556 -0.000507  0.046691
# 15224  0.018608 -0.003642  0.022637  ... -0.018976  0.006768  0.015764
# 15225  0.071874  0.061569  0.034150  ...  0.031768  0.051077  0.050300
#
#             UNH       ROG        HD        GD       FDX      COST       NKE
# ...

# %%
multiple_df2 = multiple_df * multiple_df

result = pd.concat([multiple_df, multiple_df, multiple_df], axis=1)

# %%
multiple_df2
# Out:
#            AAPL      TSLA       JPM      ADBE           AMD      NVDA  \
# 0           NaN       NaN       NaN       NaN           NaN       NaN
# 1           NaN       NaN       NaN       NaN           NaN       NaN
# 2           NaN       NaN       NaN       NaN           NaN       NaN
# 3           NaN       NaN       NaN       NaN           NaN       NaN
# 4           NaN       NaN       NaN       NaN           NaN       NaN
# ...         ...       ...       ...       ...           ...       ...
# 15221  0.000133  0.000295  0.000012  0.000138  3.422357e-05  0.000320
# 15222  0.001073  0.008751  0.000614  0.000037  7.407046e-04  0.001866
# 15223  0.000015  0.000016  0.000031  0.000042  2.278954e-07  0.000155
# 15224  0.000465  0.000019  0.000120  0.000958  2.484152e-04  0.000068
# 15225  0.000601  0.002047  0.000891  0.000865  3.182257e-03  0.003084
#
#            AMZN        FB      LRCX      MSFT  ...       AXP         GOOGL  \
# ...
